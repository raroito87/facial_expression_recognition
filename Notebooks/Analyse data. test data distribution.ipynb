# %%
from utils import ModelImporter, Preprocessing
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pre = Preprocessing('fer2013')
pre.load_data(filename='test_public_norm.csv', name='val')

X_val_df = pre.get(name='val').drop(columns=['emotion'])
y_val_df = pre.get(name='val')['emotion']

# %%
plt.figure(1, figsize=(10, 5))
plt.hist(y_val_df.values, bins = [0, 1, 2, 3, 4, 5, 6, 7])
plt.show()

# %%
pre.load_data(filename='test_private_norm.csv', name='test')

X_test_df = pre.get(name='test').drop(columns=['emotion'])
y_test_df = pre.get(name='test')['emotion']

# %%
plt.figure(1, figsize=(10, 5))
plt.hist(y_test_df.values, bins = [0, 1, 2, 3, 4, 5, 6, 7])
plt.show()

# %% [markdown]
# #### Test data has the same distribution as the training data
